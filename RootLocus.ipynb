# %%
'''Root Locus Algorithm'''

import control as ct
import numpy as np
import matplotlib.pyplot as plt

#Ogata: Example 6-1, p.273 => Figure 6-6
G = ct.tf((1), (1, 3, 2, 0))
rlist, klist = ct.rlocus(G)
plt.show()

#Ogata: Example 6-2, p.279 => Figure 6-10
G1 = ct.tf((1,2), (1, 2, 3))
#rlist, klist = ct.rlocus(G, kvect=np.linspace(100.0, -100.0, num=1000))
rlist, klist = ct.rlocus(G1)
plt.show()
